# %%
from scraper import FincaRaizScraper
from bs4 import BeautifulSoup
from datetime import datetime

# %%
fr = FincaRaizScraper()
fr.set_cities('Bogota', 'Santa Marta', 'Villavicencio', 'Medellin', 'Cali', 'Armenia', 'Fusagasuga')
fr.go(pages_per_city=5)
fr.close()
# Out:
# --------------------------------------------------------------------------------
# Number of items should be 1
# Errors: []
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Number of items should be 2
# Errors: []
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Number of items should be 3
# Errors: []
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Number of items should be 4
# Errors: []
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Number of items should be 5
# Errors: []
# ...

# %%
fr.get_dataframe().to_csv('finca_raiz_data.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 fr.get_dataframe().to_csv('finca_raiz_data.csv')
#
# File ~\Code\fincaraiz-scraper\scraper.py:56, in FincaRaizScraper.get_dataframe(self)
#      55 def get_dataframe(self):
# ---> 56     return pd.DataFrame(self.data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
for attr in fr.get_data().keys():
    print(f"{attr}:\t{len(fr.get_data()[attr])}")
# Out:
# Tipo:	597
# Propiedad:	597
# Acción:	597
# Habitaciones:	597
# Baños:	597
# Parqueaderos:	597
# Área construída:	597
# Área privada:	597
# Estrato:	597
# Estado:	597
# Piso N°:	597
# Antigüedad:	597
# Administración:	597
# Precio m²:	597
# Dirección:	597
# Barrio:	597
# Ciudad:	597
# Departamento:	597
# Características:	597
# Precio (COP):	597
# Descripción general:	597
# No. Fotos:	597
# Fecha Sacada:	598
# Fecha Publicada:	597
# Enlace:	598

# %%
data = fr.get_data()

# %%
data['Fecha Sacada'].pop()
data['Enlace'].pop()
# Out:
# 'https://www.fincaraiz.com.co/proyecto-de-vivienda/arcadia-conjunto-cerrado/calipso/cali/7418566'

# %%
import pandas as pd
pd.DataFrame(data).to_csv('finca_raiz_data_2.csv')

# %%
pd.DataFrame(data).to_pickle('finca_raiz_data_2.pkl')
