# %%
import pandas as pd
import numpy as np
pd.options.display.max_colwidth=200

# %%
df = pd.read_csv('finca_raiz_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 803 entries, 0 to 802
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           803 non-null    int64
#  1   Tipo                 803 non-null    object
#  2   Propiedad            803 non-null    object
#  3   Acción               789 non-null    object
#  4   Habitaciones         745 non-null    float64
#  5   Baños                778 non-null    object
#  6   Parqueaderos         548 non-null    object
#  7   Área construída      789 non-null    object
#  8   Área privada         789 non-null    object
#  9   Estrato              803 non-null    object
#  10  Estado               220 non-null    object
#  11  Piso N°              494 non-null    object
#  12  Antigüedad           593 non-null    object
#  13  Administración       789 non-null    object
#  14  Precio m²            789 non-null    object
#  15  Dirección            765 non-null    object
#  16  Barrio               798 non-null    object
#  17  Ciudad               803 non-null    object
#  18  Departamento         759 non-null    object
#  19  Características      664 non-null    object
#  20  Precio (COP)         789 non-null    object
#  21  Descripción general  803 non-null    object
#  22  Código Fincaraíz     275 non-null    float64
#  23  No. Fotos            803 non-null    object
#  24  Fecha Sacada         803 non-null    object
#  25  Fecha Publicada      0 non-null      float64
#  26  Enlace               803 non-null    object
# dtypes: float64(3), int64(1), object(23)
# memory usage: 169.5+ KB

# %%
df.iloc[6:13, 1:21]
# Out:
#       Tipo    Propiedad Acción  Habitaciones Baños Parqueaderos  \
# 6    Usado  Apartamento  venta           3.0     2            1
# 7    Usado         Casa  venta           4.0     1          NaN
# 8    Usado  Apartamento  venta           1.0     1          NaN
# 9    Usado         Casa  venta           NaN     1            2
# 10   Usado  Apartamento  venta           3.0     3            2
# 11   Usado         Casa  venta           8.0     3            1
# 12  Duplex  Apartamento  venta           2.0     2            1
#
#    Área construída Área privada Estrato Estado Piso N°     Antigüedad  \
# 6              66            0        4    NaN       2     1 a 8 años
# 7              96           94        2    NaN       1    9 a 15 años
# 8              35            0        4    NaN       8   16 a 30 años
# 9             135          124        2    NaN       1   16 a 30 años
# 10            109          101        5    NaN       4   16 a 30 años
# 11            320            0        3    NaN       1  ás de 30 años
# 12             73           73        4    NaN       6     1 a 8 años
#
#    Administración     Precio m²                      Dirección  \
# 6     No definida  6.818.181,82           Cr 72 bis # 152 b 25
# 7     No definida  2.083.333,33                 Cra 99 123F 23
# 8     215.000 COP     6.000.000                   Cra 7 #47-29
# 9     No definida  1.074.074,07   carrera 10A este # 56-03 sur
# 10    No definida  3.944.954,13            Carrera 53 # 104-86
# 11    No definida     3.062.500           Calle 163A # 7G - 07
# 12    688.000 COP  6.616.438,36  Calle 51 A # 3 C 34 Chapinero
#
#                         Barrio  Ciudad Departamento  \
# 6                       Bogotá  Bogotá          NaN
# 7                       Bogotá  Bogotá          NaN
# 8                       Bogotá  Bogotá          NaN
# 9   Código Fincaraíz: 10008250  Bogotá          NaN
# 10                      Bogotá  Bogotá          NaN
# 11                      Bogotá  Bogotá          NaN
# 12                      Bogotá  Bogotá          NaN
#
#                                                                                                                                                                                             Características  \
# 6                                                                                                                                                                                                       NaN
# 7                                                                                                                         ['Patio', 'Colegios / Universidades', 'Trans. Público cercano', 'Zona Comercial']
# 8                                                                                                                                                                                                       NaN
# 9                                     ['Garaje(s)', 'Cocina Integral', 'Depósito / Bodega', 'Instalación de gas', 'Patio', 'Colegios / Universidades', 'Supermercados / C.Comerciales', 'Zona Residencial']
# 10  ['Ascensor', 'Circuito cerrado de TV', 'Garaje(s)', 'Jardín', 'Parqueadero Visitantes', 'Portería / Recepción', 'Baño Auxiliar', 'Calentador', 'Chimenea', 'Citófono', 'Cocina Integral', 'Cuarto de...
# 11                                                                                                                                                                                                      NaN
# 12  ['Ascensor', 'Circuito cerrado de TV', 'En conjunto cerrado', 'Garaje(s)', 'Parqueadero Visitantes', 'Portería / Recepción', 'Balcón', 'Baño Auxiliar', 'Calentador', 'Citófono', 'Cocina Integral',...
#
#    Precio (COP)
# 6   450.000.000
# 7   200.000.000
# 8   210.000.000
# 9   145.000.000
# 10  430.000.000
# 11  980.000.000
# 12  483.000.000

# %%
df['Baños'] = df['Baños'].fillna('Finca')
df.loc[df['Baños'].str.contains('Finca'), 'Baños'] = np.nan
df['Baños'] = pd.to_numeric(df['Baños'], errors='coerce')

# %%
df['Baños'].value_counts()
# Out:
# 2.0    269
# 3.0    197
# 1.0    108
# 4.0    100
# 5.0     48
# 6.0     21
# 7.0     11
# 9.0      4
# Name: Baños, dtype: int64

# %%
df['Parqueaderos'] = df['Parqueaderos'].fillna('Finca')
df.loc[df['Parqueaderos'].str.contains('Finca'), 'Parqueaderos'] = np.nan
df['Parqueaderos'] = pd.to_numeric(df['Parqueaderos'], errors='coerce')

# %%
df['Parqueaderos'].value_counts()
# Out:
# 1.0     339
# 2.0     133
# 3.0      31
# 4.0      16
# 5.0      14
# 6.0       4
# 10.0      3
# 7.0       1
# Name: Parqueaderos, dtype: int64

# %%
df['Área construída'] = pd.to_numeric(df['Área construída'], errors='coerce')

# %%
df['Área privada'] = pd.to_numeric(df['Área privada'], errors='coerce')

# %%
col = 'Estrato'

df[col] = df[col].fillna(col)
df.loc[~df[col].str.isnumeric(), col] = np.nan
# df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
col = 'Administración'

df.loc[(df[col] == 'No definida') | (df[col].str.contains('Finca')) | (df[col].str.contains('1 COP')), col] = '0'
df[col] = pd.to_numeric(df[col].str.split('.\d\d\d', regex=True).str[0])*1000
# df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
col = 'Piso N°'

df[col] = df[col].fillna(col)
df.loc[~df[col].str.isnumeric(), col] = np.nan
df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df['Precio m²'] = df['Precio m²'].str.replace('.', '').str.replace(',', '.').astype('float64')
# Out:
# C:\Users\HaydenH\AppData\Local\Temp\ipykernel_17180\427253956.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Precio m²'] = df['Precio m²'].str.replace('.', '').str.replace(',', '.').astype('float64')

# %%
df['Ciudad'] = df['Ciudad'].replace({'Santa marta': 'Santa Marta'})

# %%
df['Características'] = df['Características'].fillna('[]').apply(pd.eval)

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()
mlb.fit(df['Características'])
df2 = pd.DataFrame(mlb.transform(df['Características']), columns=mlb.classes_)

# %%
to_drop = []
for i in df2.columns:
    if 'hace' in i or '$' in i or i[0].isnumeric() or 'inmobili' in i.lower() or 'SAS' in i or 'GRUPO' in i or 'privada' in i.lower() or 'constru' in i.lower():
        to_drop.append(i)

# %%
df2 = df2.drop(columns=to_drop)

# %%
to_drop = []
for i in df2.columns:
    if 'arrendam' in i.lower() or 'antigüe' in i.lower():
        to_drop.append(i)

df2 = df2.drop(columns=to_drop)
len(df2.columns)
# Out:
# 209

# %%
to_drop = []
for i in df2.columns:
    u = input(f'Is {i} a column you want? y/n  ')
    if u != 'y':
        to_drop.append(i)
# Out:
# Is A&N Activos y Negocios a column you want? y/n   n
# Is ADBIENES LTDA a column you want? y/n   n
# Is Planta Eléctrica a column you want? y/n   y
# Is Portería / Recepción a column you want? y/n   y
# Is Portería / Vigilancia a column you want? y/n   y
# Is Pozo de agua natural a column you want? y/n   y
# Is Precio m² a column you want? y/n   n
# Is Preguntar al anunciante a column you want? y/n   n
# Is Propiedadesynegocios.com.co a column you want? y/n   n
# Is Puerta de seguridad a column you want? y/n   y
# Is Puerta eléctrica a column you want? y/n   y
# Is Quindiovende.com a column you want? y/n   n
# Is RDB INMUEBLES a column you want? y/n   n
# Is REAL HOME BIENES RAICES S.A.S a column you want? y/n   n
# Is Redinmuebles a column you want? y/n   n
# Is Reja de Seguridad a column you want? y/n   y
# Is Reportar anuncio a column you want? y/n   n
# Is Restaurantes a column you want? y/n   y
# Is Rio / Quebrada cercano(a) a column you want? y/n   n
# Is Sala de internet a column you want? y/n   y
# Is Salón Comunal a column you want? y/n   y
# Is Salón de Juegos a column you want? y/n   y
# Is Santa Catalina - Santa Marta a column you want? y/n   n
# Is Santa Cruz - Santa Marta a column you want? y/n   n
# Is Santa Marca Finca Raiz a column you want? y/n   n
# Is Sauna / Turco / Jacuzzi a column you want? y/n   y
# Is Seguridad a column you want? y/n   y
# Is Senderos ecológicos a column you want? y/n   y
# Is Servicios Públicos a column you want? y/n   y
# Is Servicios independientes a column you want? y/n   y
# Is Shut de basura a column you want? y/n   y
# Is Sobre vía principal a column you want? y/n   y
# Is Sobre vía secundaria a column you want? y/n   y
# Is Supermercados / C.Comerciales a column you want? y/n   y
# Is Sístema de riego a column you want? y/n   y
# Is TU PROPIEDAD AQUI a column you want? y/n   n
# Is Tanques de Agua a column you want? y/n   y
# Is Terraza a column you want? y/n   y
# Is Todos los Servicios a column you want? y/n   y
# Is Trans. Público cercano a column you want? y/n   y
# Is Ubicación a column you want? y/n   n
# Is Ubicada en edificio a column you want? y/n   y
# Is Urbafincas S.A.S. a column you want? y/n   n
# Is Vanstrahlen Lawyer a column you want? y/n   n
# Is Vasquez & Vasquez sas a column you want? y/n   n
# Is Ventilación Natural a column you want? y/n   n
# Is Vigilancia a column you want? y/n   y
# Is Vigilancia 24x7 a column you want? y/n   y
# Is Vista panorámica a column you want? y/n   y
# Is Vivienda Bifamiliar a column you want? y/n   y
# Is Vivienda Multifamiliar a column you want? y/n   y
# Is Zona Campestre a column you want? y/n   y
# Is Zona Comercial a column you want? y/n   y
# Is Zona Industrial a column you want? y/n   y
# Is Zona Infantil a column you want? y/n   y
# Is Zona Residencial a column you want? y/n   y
# Is Zona de BBQ a column you want? y/n   y
# Is Zona de lavandería a column you want? y/n   y
# Is Zonas Verdes a column you want? y/n   y
# Is más de 30 años a column you want? y/n   n
# Is Árboles frutales a column you want? y/n   y
# Is Área Rural a column you want? y/n   y
# Is Área Urbana a column you want? y/n   y

# %%
df2 = df2.drop(columns=to_drop)

# %%
df2 = df2.drop(columns=df2.sum()[df2.sum() < 100].index)

# %%
df = pd.concat([df, df2], axis=1)

# %%
df['Precio (COP)'] = df['Precio (COP)'].str.replace('.', '')
# Out:
# C:\Users\HaydenH\AppData\Local\Temp\ipykernel_17180\237106218.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Precio (COP)'] = df['Precio (COP)'].str.replace('.', '')

# %%
df.drop(columns=['Unnamed: 0', 'Fecha Publicada'], inplace=True)

# %%
df.to_csv('clean_data.csv')

# %%
df.to_pickle('clean_data.pkl')
